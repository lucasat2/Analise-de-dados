# %%
import pandas as pd

# DADOS TITANIC
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
dados_pesados = pd.read_csv(url)

# %% [markdown]
# ## SCIKIT LEARNING

# %%
from sklearn.tree import DecisionTreeClassifier

# 1. Separando as "pistas" (Classe e Idade) do "alvo" (Sobreviveu ou não)
pistas = dados_limpos[['Pclass', 'Age']]
alvo = dados_limpos['Survived']

# 2. Criando o cérebro da máquina (Uma Árvore de Decisão)
robo_vidente = DecisionTreeClassifier()

# 3. Treinando o robô com os dados do Titanic (mostrando o passado para ele)
robo_vidente.fit(pistas, alvo)

print("Robô treinado e pronto para prever o futuro!")
